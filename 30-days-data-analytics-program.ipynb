# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# DAY 1 - Introduction to Data Analytics

# %% [markdown]
# ***DAY 2***

# %% [markdown]
# **Day 2 – Introduction to Python 🐍**
#
# In Day 2 of our 30 Days Data Analytics Cohort, we begin our journey with **Python**—the go-to language for data analytics, data science, machine learning, and even generative AI.
#
# Python is powerful, easy to learn, and widely used across the industry, which makes it the perfect starting point for anyone stepping into the world of data.
#
# Today, we’ll cover:
#
# * Basics of Python syntax
# * Variables and data types
# * Input and output
# * Basic operations
#
# By the end of this session, you’ll be able to write simple Python programs and build a strong foundation for the upcoming data analysis topics.
#
# Let’s get started 🚀

# %% [markdown]
# To work with data in any programming language, we need to store that data in the computer’s memory. However, we cannot access memory directly. So, we assign a name to a memory location where the data is stored. This allows us to easily access and use the data whenever needed, as long as it remains in memory.
#
# This named memory location is called a **variable**.
#
# **Definition:**
# A variable is a named memory location used to store data.

# %%
a = 10

# %% [markdown]
# `a = 10`
#
# In the above code, **`a`** is the variable name, and **`10`** is the value assigned to it. This means the value 10 is stored in a memory location, and we can access it later using the variable name `a`.

# %%
print(a)
# Out:
# 10

# %% [markdown]
# To display a value on the screen in Python, we use the `print()` function. By passing the variable name inside the `print()` function, we can see the value stored in that variable.
#
# For example, if we write `print(a)`, it will display the value assigned to `a` on the screen.

# %% [markdown]
# ## Data Types
#
# As the name suggests, data types tell us the type of data stored in a variable.
#
# In Python, the most commonly used data types are:
#
# * **int** → used for integer values
#   Example: `10`, `25`, `-7`
#
# * **float** → used for decimal values
#   Example: `10.5`, `3.14`, `-2.7`
#
# * **str** → used for text or characters
#   Example: `"hello"`, `"Python"`, `"A"`
#
# * **bool** → used for boolean values (True or False)
#   Example: `True`, `False`
#
# Python does not have a separate **char** data type because a single character is also considered a string.
#
# Similarly, unlike some other programming languages:
#
# * There is no separate **long int** or **short int** — all integer values come under **int**
# * There is no separate **double** or **long double** — decimal values come under **float**
#
# This makes Python simpler, cleaner, and easier to learn for beginners.

# %%
a = 10
b = 3.14
c = "Hello World!!"
d = True

# %%
print("Data type of a = ",type(a)) #Int Data type
print("Data type of b = ",type(b)) #Float Data type
print("Data type of c = ",type(c)) #String Data type
print("Data type of d = ",type(d)) #boolean Data Type
# Out:
# Data type of a =  <class 'int'>
# Data type of b =  <class 'float'>
# Data type of c =  <class 'str'>
# Data type of d =  <class 'bool'>

# %% [markdown]
# The `type()` function is used to find the data type of a value in Python. We can pass either the actual data or a variable name into this function.
#
# For example:
#
# * `type(10)` will return the data type of the value 10
# * `type(a)` will return the data type of the value stored in the variable `a`

# %%
print(type(10))
print(type(a))
print(type(3.14))
print(type(b))
print(type("R"))
print(type(c))
print(type(True))
print(type(d))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'str'>
# <class 'str'>
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# # Input Function
#
# The `input()` function is used to take input from the user during the execution of a program.
#
# In Python, the correct and most common way to receive input from the user is by using the `input()` function.
#
# Inside the `input()` function, we can provide a message to the user. This message is optional and is mainly used to instruct or guide the user about what value needs to be entered.
#
# The value received using the `input()` function should always be stored in a variable.
#
# By default, the `input()` function treats every value entered by the user as a **string (`str`)** data type.
#
# For example, even if the user enters:
#
# ```python
# 10
# ```
#
# Python will internally treat it as:
#
# ```python
# "10"
# ```
#
# Therefore, if we need input in a specific data type such as `int` or `float`, we must explicitly convert the input into the required data type while taking the input itself.
#
# ---
#
# # Example
#
# ```python
# name = input("Enter your name: ")
# age = int(input("Enter your age: "))
#
# print("Name:", name)
# print("Age:", age)
#
# print(type(name))
# print(type(age))
# ```
#
# ### Output
#
# ```python
# Enter your name: Rahul
# Enter your age: 20
#
# Name: Rahul
# Age: 20
#
# <class 'str'>
# <class 'int'>
# ```
#
# ---
#
# # Key Points
#
# - `input()` is used to take input from the user
# - The message inside `input()` is optional
# - Input values should be stored in variables
# - By default, every input is treated as a string
# - Use:
#   - `int()` for integer input
#   - `float()` for decimal input
#   - `str()` for text input

# %% [markdown]
# ### 🧠 Exercise Time
#
# Try solving the following questions to practice what you’ve learned:
#
# ---
#
# ## 1. Variable Creation
#
# - Create a variable named `x` and assign it a value of `50`
# - Print the value of `x`
#
# ---
#
# ## 2. Multiple Variables
#
# Create three variables:
#
# ```python
# name = "DATA"
# age = 20
# height = 5.8
# ```
#
# - Print all three values
#
# ---
#
# ## 3. Data Types
#
# - Create variables of type:
#   - `int`
#   - `float`
#   - `str`
#   - `bool`
#
# - Use the `type()` function to check their data types
#
# ---
#
# ## 4. Print Practice
#
# - Store your favorite color in a variable
# - Print the following statement:
#
# ```python
# "My favorite color is ___"
# ```
#
# ---
#
# ## 5. Input Function Practice
#
# - Take the user's name as input and print a welcome message
#
# Example Output:
#
# ```python
# Welcome Rahul
# ```
#
# ---
#
# ## 6. Integer Input
#
# - Take the user's age as input using the `input()` function
# - Convert it into an integer using `int()`
# - Print the age and its data type
#
# ---
#
# ## 7. Float Input
#
# - Take the user's height as input
# - Convert it into a float using `float()`
# - Print the value and its data type

# %% [markdown]
# # Operators in Python
#
# Operators are special symbols used to perform operations on variables and values.
#
# Python provides different types of operators for performing mathematical calculations, comparisons, assignments, and logical operations.
#
# ---
#
# # Types of Operators in Python
#
# ## 1. Arithmetic Operators
#
# Arithmetic operators are used to perform mathematical operations.
#
# | Operator | Description | Example |
# |---|---|---|
# | `+` | Addition | `10 + 5` |
# | `-` | Subtraction | `10 - 5` |
# | `*` | Multiplication | `10 * 5` |
# | `/` | Division | `10 / 5` |
# | `//` | Floor Division | `10 // 3` |
# | `%` | Modulus (Remainder) | `10 % 3` |
# | `**` | Exponent (Power) | `2 ** 3` |
#
# ---
#
# # Arithmetic Operator Example
#
# ```python
# a = 10
# b = 3
#
# print("Addition:", a + b)
# print("Subtraction:", a - b)
# print("Multiplication:", a * b)
# print("Division:", a / b)
# print("Floor Division:", a // b)
# print("Modulus:", a % b)
# print("Exponent:", a ** b)
# ```
#
# ### Output
#
# ```python
# Addition: 13
# Subtraction: 7
# Multiplication: 30
# Division: 3.3333333333333335
# Floor Division: 3
# Modulus: 1
# Exponent: 1000
# ```
#
# ---
#
# ## 2. Comparison Operators
#
# Comparison operators are used to compare two values.
#
# The result of a comparison operator is always either `True` or `False`.
#
# | Operator | Description | Example |
# |---|---|---|
# | `==` | Equal to | `a == b` |
# | `!=` | Not equal to | `a != b` |
# | `>` | Greater than | `a > b` |
# | `<` | Less than | `a < b` |
# | `>=` | Greater than or equal to | `a >= b` |
# | `<=` | Less than or equal to | `a <= b` |
#
# ---
#
# # Comparison Operator Example
#
# ```python
# a = 10
# b = 5
#
# print(a == b)
# print(a != b)
# print(a > b)
# print(a < b)
# print(a >= b)
# print(a <= b)
# ```
#
# ### Output
#
# ```python
# False
# True
# True
# False
# True
# False
# ```
#
# ---
#
# ## 3. Logical Operators
#
# Logical operators are used to combine multiple conditions.
#
# | Operator | Description |
# |---|---|
# | `and` | Returns `True` if both conditions are true |
# | `or` | Returns `True` if at least one condition is true |
# | `not` | Reverses the result |
#
# ---
#
# # Truth Table for AND Operator
#
# | A | B | A and B |
# |---|---|---|
# | True | True | True |
# | True | False | False |
# | False | True | False |
# | False | False | False |
#
# ---
#
# # Truth Table for OR Operator
#
# | A | B | A or B |
# |---|---|---|
# | True | True | True |
# | True | False | True |
# | False | True | True |
# | False | False | False |
#
# ---
#
# # Truth Table for NOT Operator
#
# | A | not A |
# |---|---|
# | True | False |
# | False | True |
#
# ---
#
# # Logical Operator Example
#
# ```python
# a = 10
# b = 5
#
# print(a > 5 and b < 10)
# print(a < 5 or b < 10)
# print(not(a > b))
# ```
#
# ### Output
#
# ```python
# True
# True
# False
# ```
#
# ---
#
# ## 4. Assignment Operators
#
# Assignment operators are used to assign values to variables.
#
# | Operator | Example | Equivalent To |
# |---|---|---|
# | `=` | `x = 5` | Assign value |
# | `+=` | `x += 2` | `x = x + 2` |
# | `-=` | `x -= 2` | `x = x - 2` |
# | `*=` | `x *= 2` | `x = x * 2` |
# | `/=` | `x /= 2` | `x = x / 2` |
#
# ---
#
# # Assignment Operator Example
#
# ```python
# x = 10
#
# x += 5
# print(x)
#
# x *= 2
# print(x)
# ```
#
# ### Output
#
# ```python
# 15
# 30
# ```
#
# ---
#
# # Operator Precedence
#
# Operator precedence defines the order in which operations are performed in an expression.
#
# Python follows a specific order while evaluating expressions. Operators with higher precedence are evaluated first.
#
# ---
#
# # Order of Operator Precedence
#
# | Precedence | Operators | Description |
# |---|---|---|
# | 1 | `()` | Parentheses |
# | 2 | `**` | Exponent |
# | 3 | `*`, `/`, `//`, `%` | Multiplication, Division, Floor Division, Modulus |
# | 4 | `+`, `-` | Addition, Subtraction |
# | 5 | `==`, `!=`, `>`, `<`, `>=`, `<=` | Comparison Operators |
# | 6 | `not` | Logical NOT |
# | 7 | `and` | Logical AND |
# | 8 | `or` | Logical OR |
# | 9 | `=`, `+=`, `-=`, `*=`, `/=` | Assignment Operators |
#
# ---
#
# # Operator Precedence Example
#
# ```python
# result = 10 + 5 * 2
# print(result)
# ```
#
# ### Output
#
# ```python
# 20
# ```
#
# Here, multiplication happens before addition.
#
# Using brackets changes the precedence:
#
# ```python
# result = (10 + 5) * 2
# print(result)
# ```
#
# ### Output
#
# ```python
# 30
# ```
#
# Here, brackets are evaluated first, so addition happens before multiplication.
#
# ---
#
# # Real-Life Example
#
# ```python
# price = 100
# quantity = 3
#
# total = price * quantity
#
# print("Total Amount =", total)
# ```
#
# ### Output
#
# ```python
# Total Amount = 300
# ```
#
# ---
#
# # Key Points
#
# - Operators are used to perform operations on variables and values
# - Arithmetic operators perform mathematical calculations
# - Comparison operators return either `True` or `False`
# - Logical operators combine multiple conditions
# - Assignment operators update variable values
# - Operator precedence decides the order of execution
# - Parentheses `()` can change the order of evaluation
# - Operators are widely used in real-world programming and problem solving

# %% [markdown]
# # Arithmetic Operators
#
# a = int(input("Enter first number: "))
# b = int(input("Enter second number: "))
#
# print("Addition =", a + b)
# print("Subtraction =", a - b)
# print("Multiplication =", a * b)
# print("Division =", a / b)
# print("Floor Division =", a // b)
# print("Modulus =", a % b)
# print("Exponent =", a ** b)

# %% [markdown]
# # Comparison Operators
#
# - Create two variables:
#   - `a = 20`
#   - `b = 15`
#
# - Print the result of:
#   - `a == b`
#   - `a != b`
#   - `a > b`
#   - `a < b`
#   - `a >= b`
#   - `a <= b`

# %% [markdown]
# # Logical Operators
#
# age = 22
# has_id = True
#
# print(age > 18 and has_id)
# print(age < 18 or has_id)
# print(not has_id)

# %% [markdown]
# # Assignment Operators
#
# x = 10
#
# x += 5
# print("After += :", x)
#
# x -= 2
# print("After -= :", x)
#
# x *= 3
# print("After *= :", x)
#
# x /= 2
# print("After /= :", x)

# %% [markdown]
# # 6. Real-Life Problem
#
# ## Problem Statement
#
# - Take the price of a product as input
# - Take the quantity as input
# - Calculate the total bill amount

# %% [markdown]
# # 7. Challenge Question 🚀
#
# ## Problem Statement
#
# - Take marks of 3 subjects as input
# - Calculate:
#   - Total Marks
#   - Average Marks
