# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/yasserh/walmart-dataset/Walmart.csv
# /kaggle/input/datasets/spscientist/students-performance-in-exams/StudentsPerformance.csv

# %% [markdown]
# # Foundations of Data Visualization
#
# ## Learning Objectives
#
# By the end of this session, you will be able to:
#
# - Understand what Data Visualization is
# - Explain why Data Visualization is important
# - Understand how Python creates visualizations
# - Use Matplotlib for creating charts
# - Understand the anatomy of a chart
# - Create Line Plots, Bar Plots, Histograms and Scatter Plots
# - Interpret visualizations and extract insights
#
# ---
#
# # The Problem
#
# Imagine a company gives you the following sales data:
#
# | Month | Sales |
# |---------|---------|
# | Jan | 100 |
# | Feb | 120 |
# | Mar | 150 |
# | Apr | 180 |
# | May | 220 |
# | Jun | 250 |
#
# You can read the numbers.
#
# But can you immediately understand:
#
# - Is sales increasing?
# - How fast is sales growing?
# - Are there any unusual patterns?
#
# Now imagine 100,000 rows instead of 6 rows.
#
# Understanding data becomes difficult.
#
# This is where Data Visualization becomes important.

# %% [markdown]
# # What is Data Visualization?
#
# Data Visualization is the graphical representation of data using charts, graphs and plots.
#
# Instead of reading thousands of rows, visualizations help us:
#
# - Identify trends
# - Compare categories
# - Understand distributions
# - Discover relationships
# - Detect outliers
#
# Visualization transforms raw data into meaningful information.
#
# ---
#
# # Why Data Visualization Matters
#
# Humans process visual information much faster than numerical information.
#
# A well-designed chart can reveal patterns that may take several minutes to identify in a table.
#
# Visualization helps analysts:
#
# - Understand data quickly
# - Communicate findings effectively
# - Support business decisions
# - Discover hidden insights
#
# Data Visualization is one of the most important stages of Data Analytics.

# %% [markdown]
# # Statistics vs Visualization
#
# In previous classes we learned:
#
# - Mean
# - Median
# - Mode
# - Range
# - Variance
# - Standard Deviation
# - Quartiles
# - IQR
#
# Statistics summarize data using numbers.
#
# Visualization helps us see those summaries.
#
# For example:
#
# A dataset may have:
#
# Mean = 70
#
# But visualization can reveal:
#
# - Whether data is symmetric
# - Whether data is skewed
# - Whether outliers exist
# - Whether groups behave differently
#
# ---
#
# Statistics tell us about data.
#
# Visualization shows us the data.

# %% [markdown]
# # How Do We Create Visualizations in Python?
#
# Now that we understand the importance of visualization, the next question is:
#
# How can we create visualizations using Python?
#
# Python provides several visualization libraries such as:
#
# - Matplotlib
# - Seaborn
# - Plotly
#
# The foundation of most Python visualizations is Matplotlib.
#
# Today we will start with Matplotlib.
#
# Later we will learn Seaborn for creating more advanced and visually appealing charts.

# %% [markdown]
# # Introduction to Matplotlib
#
# Matplotlib is one of the most widely used Python libraries for Data Visualization.
#
# Using Matplotlib we can create:
#
# - Line Plots
# - Bar Charts
# - Histograms
# - Scatter Plots
# - Pie Charts
# - Box Plots
# - Area Charts
#
# and many more.
#
# ---
#
# ## Importing Matplotlib
#
# To use Matplotlib we import the pyplot module.
#
# ```python
# import matplotlib.pyplot as plt
# ```
#
# The `pyplot` module provides functions for creating and customizing visualizations.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
year = [1,2,3,4,5]
salary = [1000,2000,1500,2500,3000]

plt.plot(year,salary)
plt.show()

# %% [markdown]
# # Anatomy of a Chart
#
# A professional visualization should clearly communicate information.
#
# The most common chart components are:
#
# ## Title
#
# Describes the chart.
#
# ## X-axis Label
#
# Describes the horizontal axis.
#
# ## Y-axis Label
#
# Describes the vertical axis.
#
# ## Grid
#
# Improves readability.
#
# ## Legend
#
# Identifies different data series.
#
# ## Colors and Markers
#
# Improve clarity and presentation.
#
# Before learning chart types, we will learn how to customize these components.

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 15, 25, 30]
plt.plot(x, y) # Plots the graph
plt.title("X VS Y") #Title of the graph
plt.xlabel("X") #Labelling the X - Axis
plt.ylabel("Y") #Labelling the Y - Axis
plt.grid(True) #To form Grid
plt.legend()
# Out:
# /tmp/ipykernel_16/3569673299.py:10: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# # Choosing the Right Chart
#
# Creating a chart is easy.
#
# Choosing the correct chart is the real skill.
#
# Every visualization answers a specific question.
#
# ---
#
# | Question | Recommended Chart |
# |-----------|------------------|
# | How does something change over time? | Line Plot |
# | Which category performs better? | Bar Plot |
# | How is data distributed? | Histogram |
# | Are two variables related? | Scatter Plot |
# | How much does each category contribute? | Pie Chart |
# | Are there outliers in the data? | Box Plot |
# | What is the spread of the data? | Box Plot |
# | How do contributions change over time? | Area Plot |
# | How can multiple visualizations be viewed together? | Subplots |
#
# ---

# %% [markdown]
# # Line Plot
#
# ## Purpose
#
# A Line Plot is used to visualize trends and changes in data over time or across an ordered sequence of observations.
#
# ---
#
# ## Real-World Scenario
#
# Imagine you own an ice cream shop.
#
# Every month, you track the number of ice creams sold. After a year, you want to understand:
#
# * During which months do customers buy the most ice cream?
# * How do seasons affect sales?
# * Which months performed best?
# * Are there any unexpected drops in sales?
#
# Instead of looking at a table of numbers, a Line Plot allows you to visualize the sales trend clearly.
#
# ---
#
# ## When Should We Use It?
#
# Use a Line Plot when:
#
# * Data is collected over time (days, weeks, months, years)
# * You want to identify trends and patterns
# * You need to monitor growth or decline
# * The order of observations is important
#
# ---
#
# ## Common Applications
#
# * Ice Cream Sales by Month
# * Monthly Sales Revenue
# * Website Traffic Growth
# * App Downloads
# * Stock Prices
# * Temperature Changes
# * Social Media Followers Over Time
# * Daily Active Users (DAU)
#
# ---
#
# ## Question Answered
#
# **"How is a value changing over time?"**
#
# ---
#
# ## Example
#
# Suppose an ice cream shop records the following monthly sales:
#
# | Month | Ice Creams Sold |
# | ----- | --------------- |
# | Jan   | 80              |
# | Feb   | 100             |
# | Mar   | 150             |
# | Apr   | 220             |
# | May   | 300             |
# | Jun   | 380             |
# | Jul   | 420             |
# | Aug   | 400             |
# | Sep   | 320             |
# | Oct   | 220             |
# | Nov   | 140             |
# | Dec   | 90              |
#
# A Line Plot helps us quickly observe:
#
# * Sales increase as the weather gets warmer
# * Peak sales occur during summer months
# * Sales decline as winter approaches
# * Seasonal patterns in customer demand
#
# We will now create a Line Plot using Matplotlib to visualize these monthly ice cream sales.

# %%
import matplotlib.pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun",
          "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]

ice_cream_sales = [80, 100, 150, 220, 300, 380,
                   420, 400, 320, 220, 140, 90]

plt.plot(months, ice_cream_sales)

plt.title("Monthly Ice Cream Sales Trend")
plt.xlabel("Month")
plt.ylabel("Ice Cream Sales")
plt.grid()

plt.show()

# %% [markdown]
# Is sales increasing or decreasing?
#
# Which month has highest sales?
#
# Is growth consistent?

# %% [markdown]
# # Bar Plot
#
# ## Purpose
#
# A Bar Plot is used to compare values across different categories.
#
# ---
#
# ## Real-World Scenario
#
# Imagine a college wants to analyze the placement performance of different engineering departments.
#
# At the end of the academic year, the placement cell collects data on the number of students placed from each department. The college management wants to identify:
#
# * Which department has the highest placements?
# * Which department needs improvement?
# * How do departments compare with each other?
#
# Instead of looking at a table of numbers, a Bar Plot makes these comparisons easy to understand.
#
# ---
#
# ## When Should We Use It?
#
# Use a Bar Plot when:
#
# * You want to compare different categories or groups
# * The categories are independent of each other
# * You want to quickly identify the highest and lowest values
#
# ---
#
# ## Common Applications
#
# * Department-wise Placement Records
# * Product Sales Comparison
# * Employee Count by Department
# * Revenue by Business Unit
# * Customer Count by Region
# * Student Enrollment by Course
#
# ---
#
# ## Question Answered
#
# **"Which category performs better?"**
#
# ---
#
# ## Example
#
# Suppose a college records the following placements across departments:
#
# | Department | Students Placed |
# | ---------- | --------------- |
# | Mechanical | 95              |
# | Civil      | 72              |
# | Electrical | 88              |
# | Chemical   | 65              |
# | Aerospace  | 54              |
#
# A Bar Plot helps us quickly observe:
#
# * Mechanical has the highest number of placements
# * Aerospace has the lowest number of placements
# * The difference in placement performance across departments
# * Which departments may need additional placement support
#
# We will now create a Bar Plot using Matplotlib to visualize department-wise placement records.

# %%
import matplotlib.pyplot as plt

departments = ["Mechanical", "Civil", "Electrical", "Chemical", "Aerospace"]
placements = [95, 72, 88, 65, 54]

colors = ["red", "blue", "green", "orange", "purple"]

plt.bar(departments, placements, color=colors)

plt.title("Department-wise Placement Record")
plt.xlabel("Department")
plt.ylabel("Students Placed")

plt.show()

# %% [markdown]
# Which department performed best?
#
# Which department performed worst?
#
# What is the difference between them?

# %% [markdown]
# # Practice Question 1: YouTube Channel Growth
#
# A YouTube creator wants to analyze how their channel has grown over the first six months of the year.
#
# The creator has recorded the total number of subscribers at the end of each month.
#
# Your task is to create a **Line Plot** to visualize the subscriber growth trend over time.
#
# ### Dataset
#
# months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
#
# subscribers = [1200, 1800, 2500, 3200, 4100, 5500]
#
# ### Requirements
#
# - Create a Line Plot
# - Add a suitable title
# - Label the x-axis and y-axis
# - Display the chart
#
# ### Questions
#
# 1. During which month did the channel have the highest subscribers?
# 2. Is the channel growing consistently?
# 3. Why is a Line Plot suitable for this scenario?

# %%
import matplotlib.pyplot as plt
months = ["Jan","Feb","Mar","Apr","May","Jun"]
subscribers = [1200,1800,2500,3200,4100,5500]
plt.plot(months,subscribers)
plt.title("Monthly Subcribers Growth Analysis")
plt.xlabel("Months")
plt.ylabel("Subscriber Count")
plt.show()

# %% [markdown]
# # Practice Question: Restaurant Menu Analysis
#
# A restaurant wants to analyze which food items are generating the highest sales.
#
# The number of orders received for each item during the weekend is given below.
#
# Your task is to create a **Bar Plot** to compare the popularity of different menu items.
#
# ### Dataset
#
# items = ["Burger", "Pizza", "Pasta", "Sandwich", "Fries"]
#
# orders = [250, 320, 180, 150, 290]
#
# ### Requirements
#
# - Create a Bar Plot
# - Use different colors for each bar
# - Add a suitable title
# - Label the x-axis and y-axis
# - Display the chart
#
# ### Questions
#
# 1. Which food item received the highest number of orders?
# 2. Which food item received the lowest number of orders?
# 3. What is the difference between the highest and lowest order counts?
# 4. Why is a Bar Plot suitable for this scenario?

# %%
items = ["Burger","Pizza","Pasta","Sandwich","Fries"]
orders = [250,320,180,150,290]
colors = ["red","blue","green","black","brown"]
plt.bar(items,orders,color = colors)
plt.title("Itemwize Order Analysis")
plt.xlabel("Item")
plt.ylabel("Order Count")
plt.show()

# %% [markdown]
# # Histogram
#
# ## Purpose
#
# A Histogram is used to understand the distribution of numerical data.
#
# Unlike a Bar Plot, a Histogram does not compare categories. Instead, it groups numerical values into ranges called **bins** and shows how many observations fall into each range.
#
# ---
#
# ## Real-World Scenario
#
# Imagine the HR department of a company wants to analyze employee salaries.
#
# The company has employees with different levels of experience, and management wants to understand:
#
# * What salary range contains the majority of employees?
# * Are most employees earning similar salaries?
# * Are there a few employees earning exceptionally high salaries?
# * How are salaries distributed across the organization?
#
# Looking at hundreds of salary records individually can be difficult. A Histogram helps summarize the distribution by grouping salaries into ranges.
#
# ---
#
# ## When Should We Use It?
#
# Use a Histogram when you want to know:
#
# * Where values are concentrated
# * How data is spread
# * Whether unusual values (outliers) exist
# * The overall shape of the data distribution
#
# ---
#
# ## How Does a Histogram Work?
#
# A Histogram automatically divides numerical data into intervals called **bins**.
#
# For example, if employee salaries range from ₹20,000 to ₹1,00,000, the Histogram may create bins such as:
#
# ```text
# 20,000 - 40,000
# 40,000 - 60,000
# 60,000 - 80,000
# 80,000 - 1,00,000
# ```
#
# It then counts how many employees fall into each salary range and displays the frequencies as bars.
#
# ---
#
# ## Can We Create Our Own Bins?
#
# Yes.
#
# By default, Matplotlib automatically decides the number of bins.
#
# However, we can control the bins ourselves.
#
# For example:
#
# ```python
# plt.hist(salaries, bins=5)
# ```
#
# This creates 5 bins.
#
# We can also define custom bin ranges:
#
# ```python
# plt.hist(salaries, bins=[20000,40000,60000,80000,100000])
# ```
#
# This creates the following bins:
#
# ```text
# 20,000 - 40,000
# 40,000 - 60,000
# 60,000 - 80,000
# 80,000 - 1,00,000
# ```
#
# This gives us more control over how the data is grouped and analyzed.
#
# ---
#
# ## Connection to Statistics
#
# Previously we learned:
#
# * Mean
# * Median
# * Range
# * Quartiles
# * IQR
#
# A Histogram helps us visualize these concepts and understand the overall distribution of data.
#
# ---
#
# ## Common Applications
#
# * Employee Salary Distribution
# * Student Marks Distribution
# * Age Distribution
# * Customer Spending Patterns
# * House Prices
# * Employee Experience Distribution
#
# ---
#
# ## Question Answered
#
# **"How is the data distributed?"**
#
# ---
#
# ## Example
#
# Suppose a company records the monthly salaries of its employees.
#
# A Histogram can help us identify:
#
# * Which salary range contains the most employees
# * Whether salaries are concentrated in a specific range
# * Whether there are unusually high salaries
# * How evenly salaries are distributed
#
# Instead of looking at individual salary values, the Histogram groups them into ranges and makes patterns easier to understand.
#
# ---
#
# ## What Can We Learn From a Histogram?
#
# A Histogram helps us identify:
#
# * Where most values are concentrated
# * Whether the data is symmetric or skewed
# * The spread of the data
# * Possible outliers
# * Gaps in the data
# * The overall shape of the distribution
#
# We will now create a Histogram using Matplotlib to visualize the distribution of employee salaries.

# %%
import matplotlib.pyplot as plt

salaries = [25000, 28000, 30000, 32000, 35000,
            38000, 40000, 42000, 45000, 48000,
            50000, 52000, 55000, 58000, 60000,
            65000, 70000, 75000, 85000, 100000]

plt.hist(salaries)

plt.title("Employee Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# # Scatter Plot
#
# ## Purpose
#
# A Scatter Plot is used to understand the relationship between two numerical variables.
#
# It helps us determine whether changes in one variable are associated with changes in another variable.
#
# ---
#
# ## Real-World Scenario
#
# Imagine you run an online store and spend money on digital advertising every month.
#
# At the end of the year, you want to understand:
#
# * Does spending more on advertisements increase sales?
# * Is there a relationship between advertising budget and revenue?
# * Are there any unusual months where high spending did not generate high sales?
#
# Instead of looking at tables of numbers, a Scatter Plot helps visualize the relationship between these two variables.
#
# ---
#
# ## When Should We Use It?
#
# Use a Scatter Plot when:
#
# * You have two numerical variables
# * You want to understand whether they are related
# * You want to identify patterns or trends
# * You want to detect unusual observations (outliers)
#
# ---
#
# ## Common Applications
#
# * Advertising Spend vs Sales
# * Experience vs Salary
# * Study Hours vs Exam Marks
# * Temperature vs Ice Cream Sales
# * House Size vs House Price
# * Website Visitors vs Revenue
#
# ---
#
# ## Question Answered
#
# **"Are two variables related?"**
#
# ---
#
# ## Example
#
# Suppose an online store records the following data:
#
# | Advertising Spend (₹) | Sales (₹) |
# | --------------------- | --------- |
# | 10,000                | 80,000    |
# | 15,000                | 1,00,000  |
# | 20,000                | 1,30,000  |
# | 25,000                | 1,55,000  |
# | 30,000                | 1,80,000  |
#
# Each point on the Scatter Plot represents one month's advertising spend and corresponding sales.
#
# By observing the plot, we can determine whether increased advertising spending is associated with increased sales.
#
# ---
#
# ## Relationship Types
#
# ### Positive Correlation
#
# As one variable increases, the other variable also increases.
#
# **Example:** Advertising Spend vs Sales
#
# ```text
# More Ads → More Sales
# ```
#
# ---
#
# ### Negative Correlation
#
# As one variable increases, the other variable decreases.
#
# **Example:** Product Price vs Number of Customers
#
# ```text
# Higher Price → Fewer Customers
# ```
#
# ---
#
# ### No Correlation
#
# No clear relationship exists between the variables.
#
# **Example:** Employee ID vs Monthly Sales
#
# ```text
# Changes in one variable do not affect the other.
# ```
#
# ---
#
# ## What Can We Learn From a Scatter Plot?
#
# A Scatter Plot helps us identify:
#
# * Whether two variables are related
# * The direction of the relationship (positive or negative)
# * The strength of the relationship
# * Unusual observations (outliers)
# * Patterns that may not be visible in a table of data
#
# We will now create a Scatter Plot using Matplotlib to visualize the relationship between advertising spend and sales.

# %%
ad_spend = [10000, 15000, 20000, 25000, 30000, 35000, 40000, 45000]

sales = [80000, 100000, 130000, 155000, 180000, 210000, 240000, 270000]

plt.scatter(ad_spend, sales)

plt.title("Advertising Spend vs Sales")
plt.xlabel("Advertising Spend (₹)")
plt.ylabel("Sales Revenue (₹)")

plt.show()

# %% [markdown]
# # Pie Chart
#
# ## Purpose
#
# A Pie Chart shows how different categories contribute to a whole.
#
# Each slice represents a proportion or percentage of the total.
#
# ---
#
# ## Real-World Scenario
#
# Imagine you are managing your monthly budget.
#
# At the end of the month, you want to understand:
#
# * How much money was spent on rent?
# * How much was spent on food?
# * How much went towards transportation?
# * Which category consumed the largest portion of your budget?
#
# Instead of looking at a table of expenses, a Pie Chart helps visualize how each expense category contributes to the total monthly spending.
#
# ---
#
# ## When Should We Use It?
#
# Use a Pie Chart when:
#
# * You want to show parts of a whole
# * Percentages or proportions are important
# * You want to compare contribution rather than exact values
#
# ---
#
# ## Common Applications
#
# * Monthly Expense Distribution
# * Market Share Analysis
# * Budget Allocation
# * Revenue Contribution by Product
# * Customer Segmentation
# * Department-wise Budget Usage
#
# ---
#
# ## Question Answered
#
# **"How much does each category contribute?"**
#
# ---
#
# ## Example
#
# Suppose a person's monthly expenses are distributed as follows:
#
# | Category       | Amount (₹) |
# | -------------- | ---------- |
# | Rent           | 20,000     |
# | Food           | 8,000      |
# | Transportation | 4,000      |
# | Entertainment  | 3,000      |
# | Savings        | 15,000     |
#
# A Pie Chart helps us quickly observe:
#
# * Which category consumes the largest portion of the budget
# * Which category contributes the least
# * The percentage contribution of each category
# * How the total budget is distributed
#
# ---
#
# ## Important Note
#
# Pie Charts work best when:
#
# * The number of categories is small
# * The categories collectively represent a whole
# * The total equals 100% (or represents a complete total)
#
# Too many slices make interpretation difficult and can reduce readability.
#
# ---
#
# ## When Not to Use a Pie Chart
#
# Avoid Pie Charts when:
#
# * There are too many categories
# * Precise comparisons are important
# * Categories do not represent parts of a whole
#
# In such cases, a Bar Plot is often a better choice.
#
# We will now create a Pie Chart using Matplotlib to visualize the distribution of monthly expenses.

# %%
categories = ["Rent", "Food", "Transportation", "Entertainment", "Savings"]

amounts = [20000, 8000, 4000, 3000, 15000]

plt.pie(amounts, labels=categories, autopct="%1.1f%%")

plt.title("Monthly Expense Distribution")

plt.show()

# %% [markdown]
# # Practice Question: Food Delivery Time Analysis
#
# A food delivery company wants to analyze how long deliveries take.
#
# The delivery time (in minutes) for 30 recent orders is given below.
#
# ### Dataset
#
# delivery_times = [18, 22, 25, 28, 30, 32, 35, 36, 38, 40,
#                   20, 24, 27, 29, 31, 34, 37, 42, 45, 50,
#                   21, 23, 26, 33, 39, 41, 43, 47, 55, 60]
#
# ### Requirements
#
# - Create a Histogram
# - Add a suitable title
# - Label both axes
# - Display the chart
#
# ### Questions
#
# 1. Which delivery time range appears most frequently?
# 2. Are there any unusually long delivery times?
# 3. Is the delivery time concentrated in a specific range?
# 4. Why is a Histogram suitable for this scenario?

# %%
delivery_times = [18, 22, 25, 28, 30, 32, 35, 36, 38, 40, 20, 24, 27, 29, 31, 34, 37, 42, 45, 50, 21, 23, 26, 33, 39, 41, 43, 47, 55, 60]
plt.hist(delivery_times)
plt.title("Deleivery time analysis")
plt.xlabel("Delivery Duration")
plt.ylabel("Delivery duration frequency")
plt.show()

# %% [markdown]
# # Practice Question: House Size vs House Price
#
# A real estate company wants to understand whether larger houses generally have higher prices.
#
# The size and price of several houses are given below.
#
# ### Dataset
#
# house_size = [800, 1000, 1200, 1400, 1600, 1800, 2000, 2200]
#
# house_price = [40, 50, 58, 65, 75, 85, 95, 110]
#
# ### Requirements
#
# - Create a Scatter Plot
# - Add a suitable title
# - Label both axes
# - Display the chart
#
# ### Questions
#
# 1. Is there a relationship between house size and house price?
# 2. Is the relationship positive or negative?
# 3. Do larger houses generally have higher prices?
# 4. Why is a Scatter Plot suitable for this scenario?

# %%
house_size = [800, 1000, 1200, 1400, 1600, 1800, 2000, 2200]

house_price = [40, 50, 58, 65, 75, 85, 95, 110]
plt.scatter(house_size,house_price)
plt.title("Size Vs Price")
plt.xlabel("size")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# # Practice Question: Smartphone Market Share
#
# A market research company records the market share of different smartphone brands.
#
# The market share percentages are given below.
#
# ### Dataset
#
# brands = ["Samsung", "Apple", "Xiaomi", "OnePlus", "Others"]
#
# market_share = [30, 25, 20, 10, 15]
#
# ### Requirements
#
# - Create a Pie Chart
# - Display category labels
# - Display percentage values on each slice
# - Add a suitable title
# - Display the chart
#
# ### Questions
#
# 1. Which brand has the largest market share?
# 2. Which brand has the smallest market share?
# 3. What percentage of the market belongs to Samsung and Apple combined?
# 4. Why is a Pie Chart suitable for this scenario?

# %%
brands = ["Samsung", "Apple", "Xiaomi", "OnePlus", "Others"]

market_share = [30, 25, 20, 10, 15]
plt.pie(market_share,labels = brands,autopct = "%1.1f%%")
plt.title("Market share of brands")
# Out:
# Text(0.5, 1.0, 'Market share of brands')

# %% [markdown]
# # Box Plot
#
# ## Purpose
#
# A Box Plot summarizes the distribution of numerical data using key statistical measures.
#
# It helps us understand the spread of the data and identify unusual values (outliers).
#
# ---
#
# ## Real-World Scenario
#
# Imagine the HR department of a company wants to analyze employee salaries.
#
# The company has employees ranging from fresh graduates to senior managers. Management wants to understand:
#
# * What is the typical salary range?
# * How spread out are employee salaries?
# * Are there employees earning unusually high or low salaries?
# * How does the salary distribution look overall?
#
# Instead of examining hundreds of salary records individually, a Box Plot provides a quick summary of the distribution.
#
# ---
#
# ## When Should We Use It?
#
# Use a Box Plot when you want to:
#
# * Detect outliers
# * Compare distributions
# * Understand the spread of data
# * Visualize key statistical measures
#
# ---
#
# ## Connection to Statistics
#
# A Box Plot is built using:
#
# * Minimum
# * First Quartile (Q1)
# * Median (Q2)
# * Third Quartile (Q3)
# * Maximum
#
# It also highlights potential outliers using the IQR (Interquartile Range) method.
#
# ---
#
# ## Example
#
# Suppose a company records the monthly salaries (₹) of its employees.
#
# A Box Plot can help us identify:
#
# * The middle 50% of salaries
# * The median salary
# * The overall spread of salaries
# * Employees whose salaries are unusually high or low
#
# For example, if most employees earn between ₹30,000 and ₹70,000 but a few executives earn ₹2,50,000+, those salaries may appear as outliers on the Box Plot.
#
# ---
#
# ## Question Answered
#
# **"Are there unusual values in the data?"**
#
# ---
#
# ## What Can We Learn From a Box Plot?
#
# A Box Plot helps us identify:
#
# * The center of the data (Median)
# * The spread of the data (IQR)
# * The range of typical values
# * Potential outliers
# * Whether the distribution is symmetric or skewed
#
# ---
#
# ## Why Is It Important?
#
# Box Plots are widely used in Data Analytics because they provide a quick statistical summary without displaying every individual data point.
#
# They are especially useful when comparing multiple groups or detecting unusual observations that may require further investigation.
#
# We will now create a Box Plot using Matplotlib to visualize employee salary distribution.

# %%
import matplotlib.pyplot as plt

salaries = [25000, 28000, 30000, 32000, 35000,
            38000, 40000, 42000, 45000, 48000,
            50000, 52000, 55000, 58000, 60000,
            65000, 70000, 75000, 85000, 250000,200000
           ]

plt.boxplot(salaries)

plt.title("Employee Salary Distribution")
plt.ylabel("Salary (₹)")

plt.show()

# %% [markdown]
# # Customization: Colors
#
# ## Why Use Colors?
#
# Colors make visualizations more attractive and easier to understand.
#
# They help:
#
# - Differentiate categories
# - Highlight important information
# - Improve visual appeal
#
# ---
#
# ## Real-World Scenario
#
# A restaurant wants to compare the number of orders received for different food items during the weekend.
#
# Using different colors for each bar makes the comparison easier to understand.
#
# ---
#
# ## Example
#
# ```python
# import matplotlib.pyplot as plt
#
# items = ["Burger", "Pizza", "Pasta", "Fries"]
#
# orders = [250, 320, 180, 290]
#
# plt.bar(
#     items,
#     orders,
#     color=["red", "blue", "green", "orange"]
# )
#
# plt.title("Weekend Food Orders")
#
# plt.show()

# %%
items = ["Burger", "Pizza", "Pasta", "Fries"]

orders = [250, 320, 180, 290]

plt.bar(
    items,
    orders,
    color=["red", "blue", "green", "orange"]
)

plt.title("Weekend Food Orders")

plt.show()

# %% [markdown]
# # Customization: Markers
#
# ## Why Use Markers?
#
# Markers help highlight individual observations in a chart.
#
# They make it easier to identify specific data points and improve readability.
#
# ---
#
# ## Real-World Scenario
#
# A real estate company wants to analyze the relationship between house size and house price.
#
# Each point on the chart represents a house.
#
# Markers help make individual houses clearly visible and distinguishable.
#
# ---
#
# ## Example
#
# ```python
# import matplotlib.pyplot as plt
#
# house_size = [800, 1000, 1200, 1400, 1600]
# house_price = [40, 55, 65, 80, 95]
#
# plt.scatter(
#     house_size,
#     house_price,
#     marker="D"
# )
#
# plt.title("House Size vs House Price")
# plt.xlabel("House Size (Sq Ft)")
# plt.ylabel("House Price (Lakhs ₹)")
#
# plt.show()
# ```
#
# ---
#
# ## Common Markers
#
# | Marker | Shape |
# |---------|--------|
# | o | Circle |
# | s | Square |
# | ^ | Triangle |
# | * | Star |
# | D | Diamond |
#
# ---
#
# ## Key Takeaway
#
# Markers help emphasize individual data points and make Scatter Plots easier to interpret.

# %%
house_size = [800, 1000, 1200, 1400, 1600]
house_price = [40, 55, 65, 80, 95]

plt.scatter(
    house_size,
    house_price,
    marker="o",
    color = "red"
)

plt.title("House Size vs House Price")
plt.xlabel("House Size (Sq Ft)")
plt.ylabel("House Price (Lakhs ₹)")

plt.show()

# %% [markdown]
# # Customization: Line Styles
#
# ## Why Use Line Styles?
#
# Line styles help differentiate multiple lines in the same chart.
#
# They improve readability when comparing trends or multiple data series.
#
# ---
#
# ## Real-World Scenario
#
# A company wants to compare monthly sales from two different years.
#
# Using different line styles makes it easier to distinguish between the years.
#
# ---
#
# ## Example
#
# ```python
# import matplotlib.pyplot as plt
#
# months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
#
# sales_2024 = [120, 150, 180, 220, 250, 280]
# sales_2025 = [140, 170, 210, 260, 300, 340]
#
# plt.plot(
#     months,
#     sales_2024,
#     linestyle="--",
#     label="2024"
# )
#
# plt.plot(
#     months,
#     sales_2025,
#     linestyle="-",
#     label="2025"
# )
#
# plt.title("Sales Comparison")
# plt.xlabel("Month")
# plt.ylabel("Sales")
# plt.legend()
#
# plt.show()
# ```
#
# ---
#
# ## Common Line Styles
#
# | Style | Meaning |
# |---------|---------|
# | "-" | Solid Line |
# | "--" | Dashed Line |
# | ":" | Dotted Line |
# | "-." | Dash-Dot Line |
#
# ---
#
# ## Key Takeaway
#
# Line styles help distinguish multiple lines and improve chart readability.

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]

sales_2024 = [120, 150, 180, 220, 250, 280]
sales_2025 = [140, 170, 210, 260, 300, 340]
plt.figure(figsize=(6,6))

plt.plot(
    months,
    sales_2024,
    linestyle=":",
    label="2024"
)

plt.plot(
    months,
    sales_2025,
    linestyle="-.",
    label="2025"
)

plt.title("Sales Comparison")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.legend()
plt.grid()

plt.show()

# %% [markdown]
# # Customization: Figure Size
#
# ## Why Change Figure Size?
#
# The default chart size may not always be suitable.
#
# Changing the figure size helps:
#
# - Improve readability
# - Prevent overlapping labels
# - Create presentation-ready charts
# - Display more information clearly
#
# ---
#
# ## Real-World Scenario
#
# A market research company wants to present smartphone market share during a business meeting.
#
# A larger chart helps the audience view labels and percentages more clearly.
#
# ---
#
# ## Example
#
# ```python
# import matplotlib.pyplot as plt
#
# brands = ["Samsung", "Apple", "Xiaomi", "OnePlus", "Others"]
#
# market_share = [30, 25, 20, 10, 15]
#
# plt.figure(figsize=(8,8))
#
# plt.pie(
#     market_share,
#     labels=brands,
#     autopct="%1.1f%%"
# )
#
# plt.title("Smartphone Market Share")
#
# plt.show()
# ```
#
# ---
#
# ## Understanding figsize
#
# ```python
# plt.figure(figsize=(8,8))
# ```
#
# | Parameter | Meaning |
# |------------|---------|
# | First Value | Width |
# | Second Value | Height |
#
# Example:
#
# ```python
# plt.figure(figsize=(10,5))
# ```
#
# Creates a chart with:
#
# - Width = 10
# - Height = 5
#
# ---
#
# ## Why Is This Important?
#
# Imagine displaying a chart in:
#
# - A presentation
# - A dashboard
# - A report
#
# Different situations require different chart sizes.
#
# ---
#
# ## Key Takeaway
#
# The `figsize` parameter controls the overall size of a visualization and helps improve readability and presentation quality.

# %%
import matplotlib.pyplot as plt

brands = ["Samsung", "Apple", "Xiaomi", "OnePlus", "Others"]

market_share = [30, 25, 20, 10, 15]

plt.figure(figsize=(8,8))

plt.pie(
    market_share,
    labels=brands,
    autopct="%1.1f%%"
)

plt.title("Smartphone Market Share")

plt.show()

# %% [markdown]
# # Customization: Grid Lines
#
# ## Why Use Grid Lines?
#
# Grid lines help users estimate values more accurately.
#
# They make charts easier to read by providing reference lines across the plot.
#
# ---
#
# ## Real-World Scenario
#
# A stock market analyst is tracking the daily closing price of a company's stock.
#
# Management wants to quickly estimate the stock price on a particular day.
#
# Grid lines make it easier to read and compare values.
#
# ---
#
# ## Example
#
# ```python
# import matplotlib.pyplot as plt
#
# days = ["Mon", "Tue", "Wed", "Thu", "Fri"]
#
# stock_price = [120, 125, 118, 130, 135]
#
# plt.plot(days, stock_price)
#
# plt.grid()
#
# plt.title("Weekly Stock Price Trend")
# plt.xlabel("Day")
# plt.ylabel("Stock Price")
#
# plt.show()
# ```
#
# ---
#
# ## Adding Grid Lines
#
# ```python
# plt.grid()
# ```
#
# This enables grid lines for the chart.
#
# ---
#
# ## Customizing Grid Lines
#
# ```python
# plt.grid(linestyle="--")
# ```
#
# Dashed grid lines.
#
# ```python
# plt.grid(color="gray")
# ```
#
# Changes grid color.
#
# ```python
# plt.grid(alpha=0.5)
# ```
#
# Makes grid lines lighter.
#
# ---
#
# ## Why Are Grid Lines Helpful?
#
# Without grid lines:
#
# - Values are harder to estimate
# - Comparisons become difficult
#
# With grid lines:
#
# - Reading values becomes easier
# - Trends become clearer
# - Charts look more professional
#
# ---
#
# ## Key Takeaway
#
# Grid lines improve readability by helping users estimate values and compare data points more accurately.

# %%
import matplotlib.pyplot as plt

days = ["Mon", "Tue", "Wed", "Thu", "Fri"]

stock_price = [120, 125, 118, 130, 135]

plt.plot(days, stock_price)

plt.grid()

plt.title("Weekly Stock Price Trend")
plt.xlabel("Day")
plt.ylabel("Stock Price")

plt.show()

# %% [markdown]
# # Customization: Legends
#
# ## Why Use Legends?
#
# Legends help identify multiple data series displayed in the same chart.
#
# Without legends, viewers may not know what each line, bar, or category represents.
#
# ---
#
# ## Real-World Scenario
#
# A company wants to compare monthly Sales and Profit.
#
# Both metrics are displayed in the same chart.
#
# A legend helps viewers easily identify which line represents Sales and which represents Profit.
#
# ---
#
# ## Example
#
# ```python
# import matplotlib.pyplot as plt
#
# months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
#
# sales = [120, 150, 180, 220, 260, 300]
# profit = [20, 30, 40, 55, 70, 90]
#
# plt.plot(months, sales, label="Sales")
# plt.plot(months, profit, label="Profit")
#
# plt.legend()
#
# plt.title("Sales vs Profit")
# plt.xlabel("Month")
# plt.ylabel("Amount")
#
# plt.show()
# ```
#
# ---
#
# ## How Does a Legend Work?
#
# Step 1: Assign a label
#
# ```python
# plt.plot(months, sales, label="Sales")
# ```
#
# Step 2: Display the legend
#
# ```python
# plt.legend()
# ```
#
# ---
#
# ## Changing Legend Position
#
# ```python
# plt.legend(loc="upper left")
# ```
#
# Common positions:
#
# ```python
# upper left
# upper right
# lower left
# lower right
# center
# ```
#
# ---
#
# ## Why Are Legends Important?
#
# Without a legend:
#
# - Multiple lines may cause confusion
# - Users cannot identify what each series represents
#
# With a legend:
#
# - Charts become easier to interpret
# - Comparisons become clearer
# - Visualizations look more professional
#
# ---
#
# ## Key Takeaway
#
# Legends help identify multiple data series and are essential whenever more than one dataset is displayed in the same chart.

# %%
import matplotlib.pyplot as plt

months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]

sales = [120, 150, 180, 220, 260, 300]
profit = [20, 30, 40, 55, 70, 90]

plt.plot(months, sales, label="Sales")
plt.plot(months, profit, label="Profit")


plt.legend(loc = "lower left")
plt.title("Sales vs Profit")
plt.xlabel("Month")
plt.ylabel("Amount")

plt.show()

# %% [markdown]
# # Customization: Rotating Axis Labels
#
# ## Why Rotate Labels?
#
# Sometimes category names are too long to fit properly on the x-axis.
#
# This can cause labels to overlap, making the chart difficult to read.
#
# Rotating the labels improves readability.
#
# ---
#
# ## Real-World Scenario
#
# A college wants to compare placement records across different departments.
#
# Some department names are long:
#
# - Mechanical Engineering
# - Civil Engineering
# - Electrical Engineering
# - Chemical Engineering
#
# Displaying these labels horizontally may cause them to overlap.
#
# ---
#
# ## Example
#
# ```python
# import matplotlib.pyplot as plt
#
# departments = [
#     "Mechanical Engineering",
#     "Civil Engineering",
#     "Electrical Engineering",
#     "Chemical Engineering"
# ]
#
# placements = [95, 72, 88, 65]
#
# plt.bar(departments, placements)
#
# plt.xticks(rotation=45)
#
# plt.title("Department-wise Placements")
# plt.xlabel("Department")
# plt.ylabel("Students Placed")
#
# plt.show()
# ```
#
# ---
#
# ## Understanding Rotation
#
# ```python
# plt.xticks(rotation=45)
# ```
#
# Common values:
#
# ```python
# rotation=0
# rotation=45
# rotation=90
# ```
#
# - 0 → Horizontal labels
# - 45 → Diagonal labels
# - 90 → Vertical labels
#
# ---
#
# ## Why Is This Useful?
#
# Rotating labels:
#
# - Prevents overlapping text
# - Improves readability
# - Makes charts look more professional
#
# ---
#
# ## Key Takeaway
#
# Use label rotation whenever category names are long and difficult to display clearly on the axis.

# %%
import matplotlib.pyplot as plt

departments = [
    "Mechanical Engineering",
    "Civil Engineering",
    "Electrical Engineering",
    "Chemical Engineering"
]

placements = [95, 72, 88, 65]

plt.bar(departments, placements,color = ["red","blue","green","yellow"])


plt.xticks(rotation=90)
plt.title("Department-wise Placements")
plt.xlabel("Department")
plt.ylabel("Students Placed")

plt.show()

# %% [markdown]
# # Customization: Subplots
#
# ## What Are Subplots?
#
# Subplots allow us to display multiple visualizations within the same figure.
#
# Instead of creating separate windows for each chart, we can organize multiple charts in a single figure.
#
# ---
#
# ## Why Do We Need Subplots?
#
# In real-world reporting and dashboards, analysts often need to compare multiple visualizations at the same time.
#
# For example:
#
# * Sales vs Profit
# * Orders vs Revenue
# * Enrollments vs Completion Rate
#
# Displaying them together makes analysis easier.
#
# ---
#
# ## Real-World Scenario
#
# An online learning platform wants to analyze:
#
# 1. Number of students enrolled in each course
# 2. Course completion rates
#
# Instead of creating two separate charts, management wants both visualizations displayed in a single report.
#
# Subplots help us achieve this.
#
# ---
#
# ## Example
#
# ```python
# import matplotlib.pyplot as plt
#
# courses = ["Python", "SQL", "Power BI", "Excel"]
#
# enrollments = [1200, 900, 750, 1000]
#
# completion_rate = [78, 82, 70, 88]
#
# plt.figure(figsize=(10,4))
#
# plt.subplot(1,2,1)
#
# plt.bar(courses, enrollments)
#
# plt.title("Course Enrollments")
#
# plt.subplot(1,2,2)
#
# plt.bar(courses, completion_rate)
#
# plt.title("Completion Rate (%)")
#
# plt.show()
# ```
#
# ---
#
# # Understanding subplot()
#
# The syntax is:
#
# ```python
# plt.subplot(rows, columns, position)
# ```
#
# Example:
#
# ```python
# plt.subplot(1,2,1)
# ```
#
# | Parameter | Meaning                  |
# | --------- | ------------------------ |
# | 1         | Number of Rows           |
# | 2         | Number of Columns        |
# | 1         | Position of Current Plot |
#
# ---
#
# # How Position Works
#
# Matplotlib numbers subplot positions from **left to right** and **top to bottom**.
#
# ---
#
# ## Example 1: One Row, Two Columns
#
# ```python
# plt.subplot(1,2,1)
# ```
#
# ```text
# +-----------+-----------+
# |     1     |     2     |
# +-----------+-----------+
# ```
#
# Position 1 → Left Plot
#
# Position 2 → Right Plot
#
# ```python
# plt.subplot(1,2,2)
# ```
#
# Creates the second plot location.
#
# ---
#
# ## Example 2: Two Rows, One Column
#
# ```python
# plt.subplot(2,1,1)
# ```
#
# ```text
# +-----------+
# |     1     |
# +-----------+
# |     2     |
# +-----------+
# ```
#
# Position 1 → Top Plot
#
# Position 2 → Bottom Plot
#
# ---
#
# ## Example 3: Two Rows, Two Columns
#
# ```python
# plt.subplot(2,2,1)
# ```
#
# ```text
# +-----------+-----------+
# |     1     |     2     |
# +-----------+-----------+
# |     3     |     4     |
# +-----------+-----------+
# ```
#
# Positions are assigned as:
#
# ```text
# 1 → Top Left
# 2 → Top Right
# 3 → Bottom Left
# 4 → Bottom Right
# ```
#
# ---
#
# ## Example 4: Three Rows, Two Columns
#
# ```python
# plt.subplot(3,2,1)
# ```
#
# ```text
# +-----------+-----------+
# |     1     |     2     |
# +-----------+-----------+
# |     3     |     4     |
# +-----------+-----------+
# |     5     |     6     |
# +-----------+-----------+
# ```
#
# Positions:
#
# ```text
# 1 → Top Left
# 2 → Top Right
# 3 → Middle Left
# 4 → Middle Right
# 5 → Bottom Left
# 6 → Bottom Right
# ```
#
# ---
#
# # Common Layouts
#
# ## Side-by-Side Charts
#
# ```python
# plt.subplot(1,2,1)
# plt.subplot(1,2,2)
# ```
#
# ```text
# +-----------+-----------+
# |  Plot 1   |  Plot 2   |
# +-----------+-----------+
# ```
#
# Useful for comparisons.
#
# ---
#
# ## Top and Bottom Charts
#
# ```python
# plt.subplot(2,1,1)
# plt.subplot(2,1,2)
# ```
#
# ```text
# +-----------+
# |  Plot 1   |
# +-----------+
# |  Plot 2   |
# +-----------+
# ```
#
# Useful when charts need more horizontal space.
#
# ---
#
# ## Dashboard Layout
#
# ```python
# plt.subplot(2,2,1)
# plt.subplot(2,2,2)
# plt.subplot(2,2,3)
# plt.subplot(2,2,4)
# ```
#
# ```text
# +-----------+-----------+
# |  Plot 1   |  Plot 2   |
# +-----------+-----------+
# |  Plot 3   |  Plot 4   |
# +-----------+-----------+
# ```
#
# Commonly used in dashboards and EDA reports.
#
# ---
#
# ## Why Are Subplots Important?
#
# Subplots help us:
#
# * Compare multiple visualizations
# * Build dashboards
# * Save space
# * Present information more effectively
# * Analyze multiple metrics simultaneously
#
# ---
#
# ## Key Takeaway
#
# Subplots allow multiple charts to be displayed within a single figure, making comparison and analysis easier.
#
# Remember:
#
# ```python
# plt.subplot(rows, columns, position)
# ```
#
# Think of it as:
#
# ```text
# How many rows?
# How many columns?
# Which position should this chart occupy?
# ```
#
# They are widely used in dashboards, reports, and exploratory data analysis (EDA).

# %%
courses = ["Python", "SQL", "Power BI", "Excel"]

enrollments = [1200, 900, 750, 1000]

completion_rate = [78, 82, 70, 88]

plt.figure(figsize=(10,4))

plt.subplot(1,2,1)

plt.bar(courses, enrollments)

plt.title("Course Enrollments")

plt.subplot(1,2,2)

plt.bar(courses, completion_rate)

plt.title("Completion Rate (%)")

plt.show()

# %% [markdown]
# # Question 1: Music Streaming Trends
#
# A music streaming platform wants to compare the number of streams for two artists over six months.
#
# ### Dataset
#
# months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
#
# artist_a = [1200, 1500, 1800, 2200, 2600, 3000]
#
# artist_b = [1000, 1300, 1700, 2100, 2400, 2800]
#
# ### Requirements
#
# 1. Plot both artists on the same chart.
# 2. Use different colors.
# 3. Use different markers.
# 4. Use different line styles.
# 5. Add a legend.
# 6. Add grid lines.
# 7. Add appropriate title and axis labels.
#
# ### Questions
#
# 1. Which artist gained more streams overall?
# 2. Why is a legend necessary here?
# 3. Which customization improved readability the most?

# %%
import matplotlib.pyplot as plt
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]

sid_sriram = [1200, 1500, 1800, 2200, 2600, 3000]

arijit = [1000, 1300, 1700, 2100, 2400, 2800]
plt.figure(figsize = (5,3))
plt.plot(months,sid_sriram,label = "Sid_Sriram",marker = "*",linestyle = "-")
plt.plot(months,arijit,label = "Arijit",marker = "^",linestyle = "--")
plt.legend()
plt.grid(True)
plt.title("Sid Sriram vs Arijit Singh Monthly Listners Analysis")
plt.xlabel("Months")
plt.ylabel("Monthly Listers")
plt.show()

# %% [markdown]
# # Question 2: Space Mission Success Rates
#
# A space agency wants to compare successful missions conducted by different countries.
#
# ### Dataset
#
# countries = [
#     "United States",
#     "Russia",
#     "China",
#     "India",
#     "Japan",
#     "European Union"
# ]
#
# missions = [340, 280, 210, 95, 85, 150]
#
# ### Requirements
#
# 1. Create a Bar Plot.
# 2. Use different colors for each bar.
# 3. Increase figure size.
# 4. Rotate x-axis labels.
# 5. Add title and axis labels.
#
# ### Questions
#
# 1. Why is label rotation useful in this chart?
# 2. Which country has the highest number of successful missions?
# 3. What happens if figure size is very small?

# %%
countries = [ "United States", "Russia", "China", "India", "Japan", "European Union" ]

missions = [340, 280, 210, 95, 85, 150]
plt.figure(figsize = (8,8))
plt.bar(countries,missions,color = ["red","yellow","green","gray","black","blue"])
plt.xticks(rotation = 45)
plt.title("Country wise Space Missions Success Rate Analysis")
plt.xlabel("Country")
plt.ylabel("Number of operations")
plt.show()

# %% [markdown]
# # Question 3: Wildlife Population Monitoring
#
# A wildlife conservation team is studying the relationship between forest area and tiger population across different reserves.
#
# ### Dataset
#
# forest_area = [500, 700, 900, 1200, 1500, 1800]
#
# tiger_population = [20, 35, 50, 75, 95, 120]
#
# ### Requirements
#
# 1. Create a Scatter Plot.
# 2. Use a custom marker.
# 3. Change the figure size.
# 4. Add grid lines.
# 5. Add title and axis labels.
#
# ### Questions
#
# 1. Is there a positive or negative relationship?
# 2. Why is a Scatter Plot suitable here?
# 3. Which customization makes individual observations easier to identify?

# %%
forest_area = [500, 700, 900, 1200, 1500, 1800]

tiger_population = [20, 35, 50, 75, 95, 120]
plt.figure(figsize = (7,7))
plt.scatter(forest_area,tiger_population,marker = "o",color = "black",label = "Tiger Population")
plt.grid(True)
plt.legend()
plt.title("Forest Area wise Tiger Population Analysis")
plt.xlabel("Forest Area")
plt.ylabel("Tiger population")
plt.show()

# %% [markdown]
# # Question 4: Theme Park Visitor Analysis
#
# A theme park records monthly visitors and monthly revenue.
#
# ### Dataset
#
# months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]
#
# visitors = [5000, 6200, 7000, 8500, 9200, 11000]
#
# revenue = [2.5, 3.1, 3.8, 4.6, 5.0, 6.2]
#
# ### Requirements
#
# 1. Plot visitors and revenue on the same chart.
# 2. Use different colors.
# 3. Use different markers.
# 4. Use different line styles.
# 5. Add legend.
# 6. Add grid.
# 7. Increase figure size.
#
# ### Questions
#
# 1. During which month was visitor growth highest?
# 2. Why is a legend important in this chart?
# 3. Which customization helps distinguish the two trends most effectively?

# %%
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun"]

visitors = [5000, 6200, 7000, 8500, 9200, 11000]

revenue = [2.5, 3.1, 3.8, 4.6, 5.0, 6.2]
plt.figure(figsize = (8,6))
plt.subplot(1,2,1)
plt.plot(months,visitors,label = "Visitors",color = "red",marker = "*",linestyle = "-")
plt.legend()
plt.grid(True)
plt.subplot(1,2,2)
plt.plot(months,revenue,label  = "revenue",color = "blue",marker = "o",linestyle = "--")
plt.legend()
plt.grid(True)

# %% [markdown]
# # Introduction to Seaborn
#
# ## What is Seaborn?
#
# Seaborn is a Python data visualization library built on top of Matplotlib.
#
# It provides:
#
# - Better looking visualizations
# - Simpler syntax
# - Built-in statistical plots
# - Direct integration with Pandas DataFrames
#
# ---
#
# ## Why Do We Need Seaborn?
#
# Previously, we used Matplotlib to create visualizations such as:
#
# - Line Plot
# - Bar Plot
# - Histogram
# - Scatter Plot
# - Pie Chart
# - Box Plot
#
# Matplotlib is powerful, but sometimes it requires more code for styling and statistical visualizations.
#
# Seaborn helps us create professional-looking charts with less code.
#
# ---
#
# ## Advantages of Seaborn
#
# ### Better Default Styling
#
# Charts look cleaner without extra customization.
#
# ### Works with DataFrames
#
# We can directly use column names from a DataFrame.
#
# ### Statistical Visualizations
#
# Seaborn provides specialized plots for Exploratory Data Analysis (EDA).
#
# ### Easy Correlation Analysis
#
# Heatmaps and Pair Plots make relationship analysis simple.
#
# ---
#
# ## Importing Seaborn
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
# ```
#
# ---
#
# ## Checking Available Datasets
#
# Seaborn provides built-in datasets for learning and practice.
#
# ```python
# sns.get_dataset_names()
# ```
#
# ---
#
# ## Loading a Dataset
#
# ```python
# tips = sns.load_dataset("tips")
# ```
#
# ---
#
# ## Viewing the Dataset
#
# ```python
# tips.head()
# ```
#
# ---
#
# ## What Will We Learn in Seaborn?
#
# 1. Count Plot
# 2. Pair Plot
# 3. Heatmap
#
# These visualizations are widely used during Exploratory Data Analysis (EDA).
#
# ---
#
# ## Key Takeaway
#
# Seaborn is built on top of Matplotlib and provides easier, more attractive, and more powerful visualizations for data analysis.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
df_list = sns.get_dataset_names()

# %%
df_list
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Count Plot
#
# ## Purpose
#
# A Count Plot is used to count the number of occurrences in each category.
#
# ---
#
# ## Question Answered
#
# **"How many records belong to each category?"**
#
# ---
#
# ## Real-World Scenario
#
# A college wants to know how many students belong to each department.
#
# Instead of manually counting records, a Count Plot automatically displays the frequency of each department.
#
# ---
#
# ## Example Dataset
#
# | Student | Department |
# |----------|-----------|
# | A | CSE |
# | B | ECE |
# | C | CSE |
# | D | Mechanical |
# | E | CSE |
# | F | ECE |
#
# ---
#
# ## Example
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# sns.countplot(
#     data=df,
#     x="Department"
# )
#
# plt.show()
# ```
#
# ---
#
# ## Common Applications
#
# - Gender Distribution
# - Department Distribution
# - Customer Segments
# - Product Categories
# - Order Status Counts
#
# ---
#
# ## Difference Between Bar Plot and Count Plot
#
# ### Bar Plot
#
# Requires summarized data.
#
# ```text
# Department | Students
# CSE        | 120
# ECE        | 90
# MECH       | 75
# ```
#
# ### Count Plot
#
# Uses raw data and performs counting automatically.
#
# ---
#
# ## Key Takeaway
#
# Count Plot automatically counts category frequencies and is one of the most commonly used EDA visualizations.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips = sns.load_dataset("tips")

sns.countplot(
    data=tips,
    x="day"
)

plt.title("Number of Customers by Day")
plt.xlabel("Day")
plt.ylabel("Count")

plt.show()

# %%
sns.countplot(
    data=tips,
    x="sex"
)

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Count")

plt.show()

# %%
sns.countplot(
    data=tips,
    x="smoker"
)

plt.title("Smoker Distribution")
plt.xlabel("Smoker")
plt.ylabel("Count")

plt.show()

# %% [markdown]
# # Pair Plot
#
# ## Purpose
#
# A Pair Plot helps us visualize relationships between multiple numerical variables at the same time.
#
# ---
#
# ## Question Answered
#
# **"What relationships exist among all numerical variables?"**
#
# ---
#
# ## Real-World Scenario
#
# A company wants to analyze:
#
# - Sales
# - Profit
# - Marketing Spend
# - Customer Count
#
# Instead of creating many Scatter Plots manually, a Pair Plot generates them automatically.
#
# ---
#
# ## Example
#
# ```python
# import seaborn as sns
#
# sns.pairplot(df)
#
# plt.show()
# ```
#
# ---
#
# ## What Does Pair Plot Show?
#
# ### Diagonal
#
# Displays distribution of each variable.
#
# ### Off-Diagonal
#
# Displays relationships between variables.
#
# ---
#
# ## Example Layout
#
# ```text
#            Sales   Profit   Customers
#
# Sales         H       S         S
#
# Profit        S       H         S
#
# Customers     S       S         H
# ```
#
# Where:
#
# ```text
# H = Histogram
# S = Scatter Plot
# ```
#
# ---
#
# ## Why Is Pair Plot Useful?
#
# It helps us:
#
# - Explore data quickly
# - Find relationships
# - Detect patterns
# - Identify outliers
#
# ---
#
# ## Key Takeaway
#
# Pair Plot automatically creates multiple Scatter Plots and distributions, making it one of the fastest EDA tools.

# %%
sns.pairplot(tips)

plt.show()

# %%
sns.pairplot(
    tips,
    hue="sex"
)

plt.show()

# %%
sns.pairplot(
    tips,
    hue="smoker"
)

plt.show()

# %% [markdown]
# # Heatmap
#
# ## Purpose
#
# A Heatmap is used to visualize relationships between numerical variables.
#
# It is commonly used to display a correlation matrix.
#
# ---
#
# ## Question Answered
#
# **"Which variables are strongly related?"**
#
# ---
#
# ## Real-World Scenario
#
# A company wants to understand how:
#
# - Sales
# - Profit
# - Advertising Spend
# - Customer Count
#
# are related to each other.
#
# A Heatmap helps visualize these relationships quickly.
#
# ---
#
# ## What is Correlation?
#
# Correlation measures how strongly two variables move together.
#
# Values range from:
#
# ```text
# -1  → Strong Negative Correlation
#
#  0  → No Correlation
#
# +1  → Strong Positive Correlation
# ```
#
# ---
#
# ## Creating a Correlation Matrix
#
# ```python
# corr = df.corr(numeric_only=True)
# ```
#
# ---
#
# ## Creating a Heatmap
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# sns.heatmap(
#     corr,
#     annot=True
# )
#
# plt.show()
# ```
#
# ---
#
# ## Understanding Colors
#
# Generally:
#
# ```text
# Darker Colors  → Strong Relationship
#
# Lighter Colors → Weak Relationship
# ```
#
# ---
#
# ## Applications
#
# - Feature Selection
# - Correlation Analysis
# - Exploratory Data Analysis
# - Machine Learning Preparation
#
# ---
#
# ## Key Takeaway
#
# Heatmaps provide a quick visual summary of relationships between variables and are one of the most important tools in EDA.

# %%
corr = tips.corr(numeric_only=True)

sns.heatmap(
    corr,
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# # Seaborn Customization
#
# ## Why Customize Seaborn Visualizations?
#
# Seaborn provides beautiful visualizations by default.
#
# However, we can further customize plots to:
#
# * Improve readability
# * Highlight important information
# * Compare multiple categories
# * Make charts presentation-ready
#
# ---
#
# # 1. Hue
#
# ## What is Hue?
#
# The `hue` parameter is used to divide data into subgroups using different colors.
#
# It allows us to compare multiple categories within the same visualization.
#
# ---
#
# ## Real-World Scenario
#
# A restaurant wants to analyze customer visits by day.
#
# In addition to the day, management also wants to know how many customers were:
#
# * Male
# * Female
#
# Instead of creating separate charts, Hue allows both categories to be displayed together.
#
# ---
#
# ## Without Hue
#
# ```python
# sns.countplot(
#     data=tips,
#     x="day"
# )
# ```
#
# ---
#
# ## With Hue
#
# ```python
# sns.countplot(
#     data=tips,
#     x="day",
#     hue="sex"
# )
# ```
#
# ---
#
# ## What Happens?
#
# ```text
# Thursday
# ├── Male
# └── Female
#
# Friday
# ├── Male
# └── Female
# ```
#
# Each subgroup receives a different color automatically.
#
# ---
#
# ## Key Takeaway
#
# Hue helps compare multiple categories within the same visualization.
#
# ---
#
# # 2. Palette
#
# ## What is Palette?
#
# A palette controls the color theme of a visualization.
#
# Instead of manually selecting colors, Seaborn provides predefined color combinations.
#
# ---
#
# ## Real-World Scenario
#
# A company is preparing a report and wants charts that match its presentation theme.
#
# Palettes help create visually appealing charts with minimal effort.
#
# ---
#
# ## Example
#
# ```python
# sns.countplot(
#     data=tips,
#     x="day",
#     palette="Set2"
# )
# ```
#
# ---
#
# ## Popular Palettes
#
# ```python
# deep
# pastel
# Set1
# Set2
# viridis
# coolwarm
# ```
#
# ---
#
# ## Another Example
#
# ```python
# sns.countplot(
#     data=tips,
#     x="day",
#     palette="pastel"
# )
# ```
#
# ---
#
# ## Key Takeaway
#
# Palettes help improve the appearance of visualizations using predefined color schemes.
#
# ---
#
# # 3. Figure Size
#
# ## Why Change Figure Size?
#
# Sometimes charts become crowded and difficult to read.
#
# Changing the figure size improves readability.
#
# ---
#
# ## Example
#
# ```python
# plt.figure(figsize=(8,5))
#
# sns.countplot(
#     data=tips,
#     x="day"
# )
# ```
#
# ---
#
# ## Understanding figsize
#
# ```python
# plt.figure(figsize=(8,5))
# ```
#
# * First Value → Width
# * Second Value → Height
#
# ---
#
# ## Key Takeaway
#
# Figure size controls the overall dimensions of the visualization.
#
# ---
#
# # 4. Displaying Values on Bars
#
# ## Why Display Values on Bars?
#
# Sometimes users want to see the exact values represented by each bar.
#
# Instead of estimating values from the axis, we can display the count directly on top of the bars.
#
# This makes charts easier to read and interpret.
#
# ---
#
# ## Real-World Scenario
#
# A restaurant wants to analyze the number of customers visiting on different days.
#
# While the bar heights show the trend, management also wants to know the exact number of customers for each day.
#
# Displaying values on the bars makes this information immediately visible.
#
# ---
#
# ## Example
#
# ```python
# import seaborn as sns
# import matplotlib.pyplot as plt
#
# tips = sns.load_dataset("tips")
#
# ax = sns.countplot(
#     data=tips,
#     x="day"
# )
#
# ax.bar_label(ax.containers[0])
#
# plt.show()
# ```
#
# ---
#
# ## What is Happening?
#
# ```python
# ax.bar_label(ax.containers[0])
# ```
#
# This command displays the value of each bar directly on the chart.
#
# ---
#
# ## Adding Space Above Labels
#
# ```python
# ax.bar_label(
#     ax.containers[0],
#     padding=3
# )
# ```
#
# The `padding` parameter adds space between the bar and the label.
#
# ---
#
# ## Common Applications
#
# * Customer Counts
# * Product Sales
# * Department-wise Placements
# * Survey Responses
# * Category Frequencies
#
# ---
#
# ## Key Takeaway
#
# Displaying values on bars improves readability and allows users to see exact values without estimating them from the axis.
#
# ---
#
# # 5. Annotating a Heatmap
#
# ## Why Use annot=True?
#
# Heatmaps use colors to represent values.
#
# Sometimes it is useful to display the actual values inside each cell.
#
# The `annot=True` parameter adds these values automatically.
#
# ---
#
# ## Without Annotation
#
# ```python
# sns.heatmap(corr)
# ```
#
# Only colors are displayed.
#
# ---
#
# ## With Annotation
#
# ```python
# sns.heatmap(
#     corr,
#     annot=True
# )
# ```
#
# ---
#
# ## What Happens?
#
# ```text
# 0.85
# 0.62
# -0.45
# ```
#
# Values are displayed inside the heatmap cells.
#
# ---
#
# ## Key Takeaway
#
# Annotation helps users see exact correlation values instead of relying only on colors.
#
# ---
#
# # 6. Color Maps (cmap)
#
# ## What is cmap?
#
# A color map controls how colors are displayed in a Heatmap.
#
# Different color maps can make relationships easier to identify.
#
# ---
#
# ## Example
#
# ```python
# sns.heatmap(
#     corr,
#     annot=True,
#     cmap="coolwarm"
# )
# ```
#
# ---
#
# ## Popular Color Maps
#
# ```python
# coolwarm
# viridis
# Blues
# Reds
# YlGnBu
# ```
#
# ---
#
# ## Another Example
#
# ```python
# sns.heatmap(
#     corr,
#     annot=True,
#     cmap="Blues"
# )
# ```
#
# ---
#
# ## Key Takeaway
#
# Color maps improve the visual interpretation of Heatmaps.
#
# ---
#
# # Summary
#
# ## Seaborn Customizations Learned
#
# | Customization | Purpose                        |
# | ------------- | ------------------------------ |
# | hue           | Compare subgroups using colors |
# | palette       | Change chart color theme       |
# | figsize       | Control chart size             |
# | bar_label()   | Display values on bars         |
# | annot         | Display values inside Heatmaps |
# | cmap          | Change Heatmap color scheme    |
#
# ---
#
# # Final Takeaway
#
# Seaborn provides attractive visualizations by default, but customization allows us to make charts more informative, readable, and presentation-ready.
#
# For most Data Analytics projects, these customizations are sufficient to create professional and insightful visualizations.

# %% [markdown]
# # From Learning Visualizations to Thinking Like a Data Analyst
#
# ---
#
# # What Have We Covered So Far?
#
# Over the last few sessions, we have learned:
#
# ## Data Handling
#
# * Python
# * NumPy
# * Pandas
#
# ## Statistics
#
# * Measures of Central Tendency
# * Measures of Dispersion
# * Outliers
# * Data Understanding
#
# ## Data Visualization
#
# Using Matplotlib and Seaborn we learned:
#
# * Line Plot
# * Bar Plot
# * Histogram
# * Scatter Plot
# * Box Plot
# * Pie Chart
# * Count Plot
# * Heatmap
# * Pair Plot
#
# We also learned:
#
# * Colors
# * Figure Size
# * Labels
# * Titles
# * Legends
# * Seaborn Customization
#
# At this point, we know how to create visualizations.
#
# But there is an important question:
#
# ```text
# Why do we create visualizations?
# ```
#
# ---
#
# # Is Data Visualization Just Creating Charts?
#
# No.
#
# Many beginners think Data Visualization means:
#
# ```text
# Dataset
#    ↓
# Create Graph
# ```
#
# This is not how real-world analytics works.
#
# In organizations, nobody asks:
#
# ```text
# Create a Histogram
# ```
#
# or
#
# ```text
# Create a Scatter Plot
# ```
#
# Businesses don't care about graph names.
#
# Businesses care about answers.
#
# ---
#
# # Then Why Do We Create Visualizations?
#
# Visualizations help us:
#
# * Understand data quickly
# * Identify patterns
# * Compare categories
# * Detect outliers
# * Find relationships
# * Support business decisions
#
# A graph is a communication tool.
#
# The goal is not the graph.
#
# The goal is the insight.
#
# ---
#
# # Where Does Visualization Fit in a Data Analytics Project?
#
# A Data Analytics project usually follows this workflow:
#
# ```text
# Business Problem
#         ↓
# Understand the Problem
#         ↓
# Ask Questions
#         ↓
# Collect Relevant Data
#         ↓
# Analyze Data
#         ↓
# Create Visualizations
#         ↓
# Observe Patterns
#         ↓
# Generate Insights
#         ↓
# Give Recommendations
#         ↓
# Business Decision
# ```
#
# Notice something important.
#
# Visualization comes in the middle of the process.
#
# It is not the starting point.
#
# ---
#
# # How Does a Data Analyst Think?
#
# A beginner thinks:
#
# ```text
# Which graph should I create?
# ```
#
# A Data Analyst thinks:
#
# ```text
# What am I trying to know?
# ```
#
# The question comes first.
#
# The graph comes later.
#
# ---
#
# # Data Analyst Workflow
#
# Whenever you see a dataset, follow this process.
#
# ```text
# Question
#     ↓
# Choose Plot
#     ↓
# Create Visualization
#     ↓
# Observation
#     ↓
# Insight
#     ↓
# Recommendation
# ```
#
# ---
#
# # Step 1: Ask a Question
#
# Every analysis starts with a question.
#
# Examples:
#
# * Which product sells the most?
# * Which city generates highest revenue?
# * How are customer ages distributed?
# * Does advertising affect sales?
# * Which department has highest salary?
#
# Without a question, there is no analysis.
#
# ---
#
# # Step 2: Choose the Appropriate Plot
#
# Different questions require different visualizations.
#
# This is why understanding plot selection is important.
#
# ---
#
# # Plot Selection Guide
#
# | Business Question                                        | Recommended Plot |
# | -------------------------------------------------------- | ---------------- |
# | How are values distributed?                              | Histogram        |
# | Are there any outliers?                                  | Box Plot         |
# | Which category appears most frequently?                  | Count Plot       |
# | Which category performs best?                            | Bar Plot         |
# | How does a value change over time?                       | Line Plot        |
# | What percentage does each category contribute?           | Pie Chart        |
# | Is there a relationship between two numerical variables? | Scatter Plot     |
# | Which variables are strongly correlated?                 | Heatmap          |
# | What patterns exist among multiple numerical variables?  | Pair Plot        |
#
# ---
#
# # Quick Plot Revision
#
# ## Line Plot
#
# ### Use When
#
# You want to analyze trends over time.
#
# Questions:
#
# * How are monthly sales changing?
# * Is revenue increasing?
# * How has website traffic changed?
#
# Think:
#
# ```text
# Trend Over Time
# ```
#
# ---
#
# ## Bar Plot
#
# ### Use When
#
# You want to compare categories.
#
# Questions:
#
# * Which city has highest sales?
# * Which department has highest salary?
# * Which product sells most?
#
# Think:
#
# ```text
# Category Comparison
# ```
#
# ---
#
# ## Histogram
#
# ### Use When
#
# You want to understand distribution.
#
# Questions:
#
# * How are salaries distributed?
# * How are ages distributed?
# * How are sales distributed?
#
# Think:
#
# ```text
# One Numerical Variable
# ```
#
# ---
#
# ## Box Plot
#
# ### Use When
#
# You want to identify outliers or compare spread.
#
# Questions:
#
# * Are there unusual salaries?
# * Are there sales outliers?
# * Which department has more variation?
#
# Think:
#
# ```text
# Outlier Detection
# ```
#
# ---
#
# ## Scatter Plot
#
# ### Use When
#
# You want to study relationships.
#
# Questions:
#
# * Does advertising affect sales?
# * Does age affect income?
# * Does bill amount affect tip?
#
# Think:
#
# ```text
# Relationship Between Two Numerical Variables
# ```
#
# ---
#
# ## Pie Chart
#
# ### Use When
#
# You want to show proportions.
#
# Questions:
#
# * What percentage of sales comes from each category?
# * What percentage of employees belong to each department?
#
# Think:
#
# ```text
# Part of a Whole
# ```
#
# ---
#
# ## Count Plot
#
# ### Use When
#
# You want to count occurrences.
#
# Questions:
#
# * Which day has the most customers?
# * How many students belong to each department?
# * How many passengers survived?
#
# Think:
#
# ```text
# Frequency Counts
# ```
#
# ---
#
# ## Heatmap
#
# ### Use When
#
# You want to analyze correlations.
#
# Questions:
#
# * Which variables move together?
# * Which variables influence sales?
#
# Think:
#
# ```text
# Multiple Relationships
# ```
#
# ---
#
# ## Pair Plot
#
# ### Use When
#
# You want a quick overview of numerical variables.
#
# Questions:
#
# * What patterns exist?
# * Which variables seem related?
#
# Think:
#
# ```text
# Dataset Exploration
# ```
#
# ---
#
# # Real Data Analyst Example
#
# Let us now understand how a Data Analyst works using a real business scenario.
#
# ---
#
# # Business Situation
#
# A restaurant owner says:
#
# ```text
# I feel weekends are much busier than weekdays.
# Can you verify this using data?
# ```
#
# Notice something important.
#
# The owner did NOT ask for a graph.
#
# The owner asked a business question.
#
# ---
#
# # Step 1: Understand the Problem
#
# The problem is:
#
# ```text
# Is customer traffic higher during weekends?
# ```
#
# ---
#
# # Step 2: Convert Problem Into a Data Question
#
# The analyst asks:
#
# ```text
# Which day receives the highest number of customers?
# ```
#
# Now we have a measurable question.
#
# ---
#
# # Step 3: Understand the Data
#
# Available Column:
#
# ```text
# day
# ```
#
# Possible Values:
#
# ```text
# Thursday
# Friday
# Saturday
# Sunday
# ```
#
# ---
#
# # Step 4: Select Appropriate Plot
#
# Ask yourself:
#
# ```text
# Am I analyzing numbers?
#
# No
#
# Am I counting categories?
#
# Yes
# ```
#
# Best Plot:
#
# ```text
# Count Plot
# ```
#
# ---
#
# # Step 5: Create Visualization
#
# ```python
# sns.countplot(
#     data=tips,
#     x="day"
# )
# ```
#
# ---
#
# # Step 6: Observation
#
# The graph shows:
#
# ```text
# Saturday has the highest customer count.
# ```
#
# This is called an Observation.
#
# Observation means:
#
# ```text
# What do I see?
# ```
#
# ---
#
# # Step 7: Insight
#
# Now ask:
#
# ```text
# Why might this be happening?
# ```
#
# Possible Insight:
#
# ```text
# Customers prefer dining out on weekends.
# ```
#
# Insight means:
#
# ```text
# What does this pattern mean?
# ```
#
# ---
#
# # Step 8: Recommendation
#
# Now ask:
#
# ```text
# What action should the business take?
# ```
#
# Recommendation:
#
# ```text
# Increase staff availability during weekends.
# ```
#
# ---
#
# # Step 9: Business Decision
#
# Management decides:
#
# ```text
# Add additional staff on Saturdays and Sundays.
# ```
#
# Now the analysis has created business value.
#
# ---
#
# # What Actually Happened?
#
# Notice the complete workflow.
#
# ```text
# Business Problem
#         ↓
# Question
#         ↓
# Choose Plot
#         ↓
# Visualization
#         ↓
# Observation
#         ↓
# Insight
#         ↓
# Recommendation
#         ↓
# Decision
# ```
#
# The graph was only one step.
#
# The real objective was helping the business make a better decision.
#
# ---
#
# # Observation vs Insight vs Recommendation
#
# Students often confuse these terms.
#
# ## Observation
#
# ```text
# Saturday has the highest customer count.
# ```
#
# This is what the graph shows.
#
# ---
#
# ## Insight
#
# ```text
# Customer traffic increases during weekends.
# ```
#
# This explains the pattern.
#
# ---
#
# ## Recommendation
#
# ```text
# Increase staffing on weekends.
# ```
#
# This suggests an action.
#
# ---
#
# # The Golden Rule of Data Analytics
#
# Never stop at:
#
# ```text
# Observation
# ```
#
# Always continue to:
#
# ```text
# Observation
#       ↓
# Insight
#       ↓
# Recommendation
# ```
#
# Because businesses do not pay analysts for charts.
#
# Businesses pay analysts for decisions.
#
# ---
#
# # Final Takeaway
#
# Whenever you work with a dataset, remember:
#
# ```text
# Understand Problem
#         ↓
# Ask Question
#         ↓
# Choose Plot
#         ↓
# Create Visualization
#         ↓
# Observation
#         ↓
# Insight
#         ↓
# Recommendation
#         ↓
# Decision
# ```
#
# And remember:
#
# ```text
# Histogram  → Distribution
#
# Box Plot   → Outliers
#
# Count Plot → Counts
#
# Bar Plot   → Comparison
#
# Line Plot  → Trends
#
# Pie Chart  → Proportions
#
# Scatter Plot → Relationships
#
# Heatmap → Correlations
#
# Pair Plot → Exploration
# ```
#
# A Data Analyst does not start with a graph.
#
# A Data Analyst starts with a question.
#
# The graph is simply a tool used to answer that question.

# %%
df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 182 entries, 1 to 889
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     182 non-null    int64
#  1   pclass       182 non-null    int64
#  2   sex          182 non-null    object
#  3   age          182 non-null    float64
#  4   sibsp        182 non-null    int64
#  5   parch        182 non-null    int64
#  6   fare         182 non-null    float64
#  7   embarked     182 non-null    object
#  8   class        182 non-null    category
#  9   who          182 non-null    object
#  10  adult_male   182 non-null    bool
#  11  deck         182 non-null    category
#  12  embark_town  182 non-null    object
#  13  alive        182 non-null    object
#  14  alone        182 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 18.2+ KB
